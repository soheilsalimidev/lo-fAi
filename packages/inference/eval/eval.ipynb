# %%
import os
import sys
from music21 import converter, note, chord, key, harmony
import sys

sys.path.append("./../../model")
sys.path.append("./../../model/src/tokenizer")
os.environ["RWKV_JIT_ON"] = "1"
os.environ["RWKV_CUDA_ON"] = "0"

# %%
def analyze_melodic_similarity(score, reference_score):
    generated_melody = score.flat.notes
    reference_melody = reference_score.flat.notes
    generated_pitches = [
        n.pitch.midi for n in generated_melody if isinstance(n, note.Note)]
    reference_pitches = [
        n.pitch.midi for n in reference_melody if isinstance(n, note.Note)]
    matching_pitches = sum(1 for gp, rp in zip(
        generated_pitches, reference_pitches) if gp == rp)
    similarity_ratio = matching_pitches / \
        min(len(generated_pitches), len(reference_pitches))
    return similarity_ratio

# %%
def analyze_rhythm_consistency(score):
    notes = score.flat.notes
    durations = [n.quarterLength for n in notes if isinstance(n, note.Note)]
    mean_duration = sum(durations) / len(durations)
    variance = sum((d - mean_duration) **
                   2 for d in durations) / len(durations)
    std_dev = variance ** 0.5
    return std_dev

# %%
def analyze_harmonic_coherence(score):
    key_analysis = score.analyze('key')

    chords = score.chordify()
    chord_list = [ch for ch in chords.recurse().getElementsByClass('Chord')]

    consonance_count = sum(1 for ch in chord_list if ch.isConsonant())
    dissonance_count = len(chord_list) - consonance_count
    total_chords = len(chord_list)
    consonance_ratio = consonance_count / total_chords
    dissonance_ratio = dissonance_count / total_chords

    return consonance_ratio, dissonance_ratio

# %%
def analyze_tonal_stability(score):
    key_changes = score.flat.getElementsByClass(key.Key)
    num_key_changes = len(key_changes)
    return num_key_changes

# %%
import logging
import glob
import uuid
from concurrent.futures import ThreadPoolExecutor
from multiprocessing import Pool
sys.path.append("./../../model/src/tokenizer")
print(sys.path)
from rwkv.utils import PIPELINE, PIPELINE_ARGS
from rwkv.model import RWKV
from src.tokenizer.midi_to_str import convert_midi_bytes_to_str
from src.tokenizer.midi_util import convert_str_to_midi

model = RWKV(model='./../../../rwkv-pinao.pth', strategy="cpu fp32")
pipeline = PIPELINE(
    model, './../../model/src/tokenizer/tokenizer-midi/tokenizer.json')
args = PIPELINE_ARGS(
    temperature=1.0,
    top_p=0.8,
    top_k=8,
    # alpha_frequency=0.25,
    # alpha_presence=0.25,
    alpha_decay=0.997,  # gradually decay the penalty
    token_stop=["<end>"],
    chunk_len=512,
)

# Set up logging
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)


def analyze_midi_file(filename):
    """
    Analyze a single MIDI file and calculate metrics.
    """
    output_filename = f"mdiOut_{uuid.uuid4()}.mid"
    logger.info(f"Processing file: {filename}")
    with open(os.path.join('./validation', filename), 'rb') as f:
        data = []
        pipeline.generate(
            convert_midi_bytes_to_str(None, ('', f.read()))[1][0], args=args, callback=lambda token: data.append(token))
        convert_str_to_midi(" ".join(map(str, data)), 300, 0).save(
            output_filename
        )
    reference_score = converter.parse(os.path.join('./validation', filename))
    score = converter.parse(output_filename)
    logger.info(f"Finished processing file: {filename}")
    return {
        'rhythm_consistency': analyze_rhythm_consistency(score),
        'consonance_ratio': analyze_harmonic_coherence(score)[0],
        'dissonance_ratio': analyze_harmonic_coherence(score)[1],
        'melodic_similarity': analyze_melodic_similarity(score, reference_score),
        'tonal_stability': analyze_tonal_stability(score)
    }


def calculate_metrics():
    """
    Calculate overall metrics for all MIDI files in the validation directory.
    """
    total = 0
    metrics = {'rhythm_consistency': 0, 'consonance_ratio': 0,
               'dissonance_ratio': 0, 'melodic_similarity': 0, 'tonal_stability': 0}
    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = []
        for filename in os.listdir('./validation')[:100]:
            if filename.endswith(".mid") or filename.endswith(".midi"):
                futures.append(executor.submit(analyze_midi_file, filename))
        for i, future in enumerate(futures):
            result = future.result()
            total += 1
            for metric, value in result.items():
                metrics[metric] += value
            logger.info(f"Processed {total} files")
            if i % 10 == 0:
                logger.info(
                    f"  {metric.capitalize().replace('_', ' ')}: {value / total:.2f}")
    logger.info(
        f"  {metric.capitalize().replace('_', ' ')}: {value / total:.2f}")
    for metric, value in metrics.items():
        logger.info(
            f"  {metric.capitalize().replace('_', ' ')}: {value / total:.2f}")

calculate_metrics()
# Out:
# ['/home/arthur/miniconda3/envs/AItuneCraft/lib/python310.zip', '/home/arthur/miniconda3/envs/AItuneCraft/lib/python3.10', '/home/arthur/miniconda3/envs/AItuneCraft/lib/python3.10/lib-dynload', '', '/home/arthur/.local/lib/python3.10/site-packages', '/home/arthur/miniconda3/envs/AItuneCraft/lib/python3.10/site-packages', './../../model', './../../model/src/tokenizer', './../../model/src/tokenizer', './../../model/src/tokenizer']
# RWKV_JIT_ON 1 RWKV_CUDA_ON 0 RESCALE_LAYER 0
#
# Loading ./../../../rwkv-pinao.pth ...
# Model detected: v6.0
# Strategy: (total 20+1=21 layers)
# * cpu [float32, float32], store 21 layers
# 0-cpu-float32-float32 1-cpu-float32-float32 2-cpu-float32-float32 3-cpu-float32-float32 4-cpu-float32-float32 5-cpu-float32-float32 6-cpu-float32-float32 7-cpu-float32-float32 8-cpu-float32-float32 9-cpu-float32-float32 10-cpu-float32-float32 11-cpu-float32-float32 12-cpu-float32-float32 13-cpu-float32-float32 14-cpu-float32-float32 15-cpu-float32-float32 16-cpu-float32-float32 17-cpu-float32-float32 18-cpu-float32-float32 19-cpu-float32-float32 20-cpu-float32-float32
# emb.weight                        f32      cpu   2176   512
# blocks.0.ln1.weight               f32      cpu    512
# blocks.0.ln1.bias                 f32      cpu    512
# blocks.0.ln2.weight               f32      cpu    512
# blocks.0.ln2.bias                 f32      cpu    512
# blocks.0.att.time_maa_x           f32      cpu    512
# blocks.0.att.time_maa_w           f32      cpu    512
# blocks.0.att.time_maa_k           f32      cpu    512
# blocks.0.att.time_maa_v           f32      cpu    512
# blocks.0.att.time_maa_r           f32      cpu    512
# blocks.0.att.time_maa_g           f32      cpu    512
# blocks.0.att.time_maa_w1          f32      cpu    512   160
# blocks.0.att.time_maa_w2          f32      cpu      5    32   512
# blocks.0.att.time_decay           f32      cpu      8    64
# blocks.0.att.time_decay_w1        f32      cpu    512    64
# blocks.0.att.time_decay_w2        f32      cpu     64   512
# blocks.0.att.time_first           f32      cpu      8    64
# blocks.0.att.receptance.weight    f32      cpu    512   512
# blocks.0.att.key.weight           f32      cpu    512   512
# blocks.0.att.value.weight         f32      cpu    512   512
# blocks.0.att.output.weight        f32      cpu    512   512
# blocks.0.att.gate.weight          f32      cpu    512   512
# blocks.0.att.ln_x.weight          f32      cpu    512
# blocks.0.att.ln_x.bias            f32      cpu    512
# blocks.0.ffn.time_maa_k           f32      cpu    512
# blocks.0.ffn.time_maa_r           f32      cpu    512
# blocks.0.ffn.key.weight           f32      cpu    512  1792
# blocks.0.ffn.receptance.weight    f32      cpu    512   512
# blocks.0.ffn.value.weight         f32      cpu   1792   512
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# blocks.19.ln1.weight              f32      cpu    512
# blocks.19.ln1.bias                f32      cpu    512
# blocks.19.ln2.weight              f32      cpu    512
# blocks.19.ln2.bias                f32      cpu    512
# blocks.19.att.time_maa_x          f32      cpu    512
# blocks.19.att.time_maa_w          f32      cpu    512
# blocks.19.att.time_maa_k          f32      cpu    512
# blocks.19.att.time_maa_v          f32      cpu    512
# blocks.19.att.time_maa_r          f32      cpu    512
# blocks.19.att.time_maa_g          f32      cpu    512
# blocks.19.att.time_maa_w1         f32      cpu    512   160
# blocks.19.att.time_maa_w2         f32      cpu      5    32   512
# blocks.19.att.time_decay          f32      cpu      8    64
# blocks.19.att.time_decay_w1       f32      cpu    512    64
# blocks.19.att.time_decay_w2       f32      cpu     64   512
# blocks.19.att.time_first          f32      cpu      8    64
# blocks.19.att.receptance.weight   f32      cpu    512   512
# blocks.19.att.key.weight          f32      cpu    512   512
# blocks.19.att.value.weight        f32      cpu    512   512
# blocks.19.att.output.weight       f32      cpu    512   512
# blocks.19.att.gate.weight         f32      cpu    512   512
# blocks.19.att.ln_x.weight         f32      cpu    512
# blocks.19.att.ln_x.bias           f32      cpu    512
# blocks.19.ffn.time_maa_k          f32      cpu    512
# blocks.19.ffn.time_maa_r          f32      cpu    512
# blocks.19.ffn.key.weight          f32      cpu    512  1792
# blocks.19.ffn.receptance.weight   f32      cpu    512   512
# blocks.19.ffn.value.weight        f32      cpu   1792   512
# ln_out.weight                     f32      cpu    512
# ln_out.bias                       f32      cpu    512
# head.weight                       f32      cpu    512  2176
# 2024-09-18 00:53:33,169 - INFO - Processing file: 1.mid
# 2024-09-18 00:53:33,171 - INFO - Processing file: 10.mid
# 2024-09-18 00:53:33,172 - INFO - Processing file: 100.mid
# 2024-09-18 00:53:33,172 - INFO - Processing file: 1000.mid
# 2024-09-18 00:53:33,173 - INFO - Processing file: 1001.mid
# 2024-09-18 00:53:47,461 - INFO - Finished processing file: 1001.mid
# 2024-09-18 00:53:47,672 - INFO - Processing file: 1002.mid
# 2024-09-18 00:53:47,909 - INFO - Finished processing file: 1.mid
# 2024-09-18 00:53:48,150 - INFO - Processing file: 1003.mid
# 2024-09-18 00:53:48,150 - INFO - Processed 1 files
# 2024-09-18 00:53:48,153 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:53:49,044 - INFO - Finished processing file: 100.mid
# 2024-09-18 00:53:49,403 - INFO - Processing file: 1004.mid
# 2024-09-18 00:53:51,426 - INFO - Finished processing file: 1000.mid
# 2024-09-18 00:53:51,670 - INFO - Processing file: 1005.mid
# 2024-09-18 00:53:59,115 - INFO - Finished processing file: 10.mid
# 2024-09-18 00:53:59,404 - INFO - Processing file: 1006.mid
# 2024-09-18 00:53:59,405 - INFO - Processed 2 files
# 2024-09-18 00:53:59,408 - INFO - Processed 3 files
# 2024-09-18 00:53:59,409 - INFO - Processed 4 files
# 2024-09-18 00:53:59,410 - INFO - Processed 5 files
# 2024-09-18 00:54:02,728 - INFO - Finished processing file: 1002.mid
# 2024-09-18 00:54:02,939 - INFO - Processing file: 1007.mid
# 2024-09-18 00:54:02,939 - INFO - Processed 6 files
# 2024-09-18 00:54:06,713 - INFO - Finished processing file: 1005.mid
# 2024-09-18 00:54:06,910 - INFO - Processing file: 1008.mid
# 2024-09-18 00:54:08,964 - INFO - Finished processing file: 1004.mid
# 2024-09-18 00:54:09,188 - INFO - Processing file: 1009.mid
# 2024-09-18 00:54:09,688 - INFO - Finished processing file: 1003.mid
# 2024-09-18 00:54:09,925 - INFO - Processing file: 101.mid
# 2024-09-18 00:54:09,925 - INFO - Processed 7 files
# 2024-09-18 00:54:09,929 - INFO - Processed 8 files
# 2024-09-18 00:54:09,930 - INFO - Processed 9 files
# 2024-09-18 00:54:14,223 - INFO - Finished processing file: 1006.mid
# 2024-09-18 00:54:14,543 - INFO - Processing file: 1010.mid
# 2024-09-18 00:54:14,544 - INFO - Processed 10 files
# 2024-09-18 00:54:15,480 - INFO - Finished processing file: 1007.mid
# 2024-09-18 00:54:15,709 - INFO - Processing file: 1011.mid
# 2024-09-18 00:54:15,709 - INFO - Processed 11 files
# 2024-09-18 00:54:15,711 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:54:23,401 - INFO - Finished processing file: 1008.mid
# 2024-09-18 00:54:23,626 - INFO - Processing file: 1012.mid
# 2024-09-18 00:54:23,627 - INFO - Processed 12 files
# 2024-09-18 00:54:24,107 - INFO - Finished processing file: 101.mid
# 2024-09-18 00:54:24,391 - INFO - Processing file: 1013.mid
# 2024-09-18 00:54:28,205 - INFO - Finished processing file: 1009.mid
# 2024-09-18 00:54:28,413 - INFO - Processing file: 1014.mid
# 2024-09-18 00:54:28,413 - INFO - Processed 13 files
# 2024-09-18 00:54:28,416 - INFO - Processed 14 files
# 2024-09-18 00:54:31,061 - INFO - Finished processing file: 1011.mid
# 2024-09-18 00:54:31,427 - INFO - Processing file: 1015.mid
# 2024-09-18 00:54:34,227 - INFO - Finished processing file: 1010.mid
# 2024-09-18 00:54:34,483 - INFO - Processing file: 1016.mid
# 2024-09-18 00:54:34,483 - INFO - Processed 15 files
# 2024-09-18 00:54:34,486 - INFO - Processed 16 files
# 2024-09-18 00:54:39,328 - INFO - Finished processing file: 1013.mid
# 2024-09-18 00:54:39,536 - INFO - Processing file: 1017.mid
# 2024-09-18 00:54:42,355 - INFO - Finished processing file: 1014.mid
# 2024-09-18 00:54:42,635 - INFO - Processing file: 1018.mid
# 2024-09-18 00:54:48,033 - INFO - Finished processing file: 1015.mid
# 2024-09-18 00:54:48,243 - INFO - Processing file: 1019.mid
# 2024-09-18 00:54:49,121 - INFO - Finished processing file: 1016.mid
# 2024-09-18 00:54:49,326 - INFO - Processing file: 102.mid
# 2024-09-18 00:54:51,696 - INFO - Finished processing file: 1012.mid
# 2024-09-18 00:54:51,962 - INFO - Processing file: 1020.mid
# 2024-09-18 00:54:51,962 - INFO - Processed 17 files
# 2024-09-18 00:54:51,965 - INFO - Processed 18 files
# 2024-09-18 00:54:51,966 - INFO - Processed 19 files
# 2024-09-18 00:54:51,967 - INFO - Processed 20 files
# 2024-09-18 00:54:51,968 - INFO - Processed 21 files
# 2024-09-18 00:54:51,982 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:54:54,746 - INFO - Finished processing file: 1017.mid
# 2024-09-18 00:54:55,012 - INFO - Processing file: 1021.mid
# 2024-09-18 00:54:55,012 - INFO - Processed 22 files
# 2024-09-18 00:54:57,700 - INFO - Finished processing file: 1018.mid
# 2024-09-18 00:54:57,971 - INFO - Processing file: 1022.mid
# 2024-09-18 00:54:57,971 - INFO - Processed 23 files
# 2024-09-18 00:55:05,292 - INFO - Finished processing file: 102.mid
# 2024-09-18 00:55:05,487 - INFO - Processing file: 1023.mid
# 2024-09-18 00:55:08,304 - INFO - Finished processing file: 1019.mid
# 2024-09-18 00:55:08,649 - INFO - Processing file: 1024.mid
# 2024-09-18 00:55:08,650 - INFO - Processed 24 files
# 2024-09-18 00:55:08,652 - INFO - Processed 25 files
# 2024-09-18 00:55:09,119 - INFO - Finished processing file: 1021.mid
# 2024-09-18 00:55:09,316 - INFO - Processing file: 1025.mid
# 2024-09-18 00:55:13,925 - INFO - Finished processing file: 1022.mid
# 2024-09-18 00:55:14,138 - INFO - Processing file: 1026.mid
# 2024-09-18 00:55:14,427 - INFO - Finished processing file: 1020.mid
# 2024-09-18 00:55:14,707 - INFO - Processing file: 1027.mid
# 2024-09-18 00:55:14,708 - INFO - Processed 26 files
# 2024-09-18 00:55:14,710 - INFO - Processed 27 files
# 2024-09-18 00:55:14,711 - INFO - Processed 28 files
# 2024-09-18 00:55:20,128 - INFO - Finished processing file: 1023.mid
# 2024-09-18 00:55:20,357 - INFO - Processing file: 1028.mid
# 2024-09-18 00:55:20,359 - INFO - Processed 29 files
# 2024-09-18 00:55:23,414 - INFO - Finished processing file: 1025.mid
# 2024-09-18 00:55:23,737 - INFO - Processing file: 1029.mid
# 2024-09-18 00:55:28,192 - INFO - Finished processing file: 1024.mid
# 2024-09-18 00:55:28,411 - INFO - Processing file: 103.mid
# 2024-09-18 00:55:28,411 - INFO - Processed 30 files
# 2024-09-18 00:55:28,414 - INFO - Processed 31 files
# 2024-09-18 00:55:28,415 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:55:29,267 - INFO - Finished processing file: 1026.mid
# 2024-09-18 00:55:29,528 - INFO - Processing file: 1030.mid
# 2024-09-18 00:55:29,529 - INFO - Processed 32 files
# 2024-09-18 00:55:33,612 - INFO - Finished processing file: 1027.mid
# 2024-09-18 00:55:33,842 - INFO - Processing file: 1031.mid
# 2024-09-18 00:55:33,843 - INFO - Processed 33 files
# 2024-09-18 00:55:34,723 - INFO - Finished processing file: 1028.mid
# 2024-09-18 00:55:34,971 - INFO - Processing file: 1032.mid
# 2024-09-18 00:55:34,971 - INFO - Processed 34 files
# 2024-09-18 00:55:41,096 - INFO - Finished processing file: 103.mid
# 2024-09-18 00:55:41,422 - INFO - Processing file: 1033.mid
# 2024-09-18 00:55:43,164 - INFO - Finished processing file: 1029.mid
# 2024-09-18 00:55:43,401 - INFO - Processing file: 1034.mid
# 2024-09-18 00:55:43,401 - INFO - Processed 35 files
# 2024-09-18 00:55:43,404 - INFO - Processed 36 files
# 2024-09-18 00:55:47,835 - INFO - Finished processing file: 1030.mid
# 2024-09-18 00:55:48,051 - INFO - Processing file: 1035.mid
# 2024-09-18 00:55:48,052 - INFO - Processed 37 files
# 2024-09-18 00:55:49,667 - INFO - Finished processing file: 1031.mid
# 2024-09-18 00:55:49,982 - INFO - Processing file: 1036.mid
# 2024-09-18 00:55:49,982 - INFO - Processed 38 files
# 2024-09-18 00:55:54,991 - INFO - Finished processing file: 1033.mid
# 2024-09-18 00:55:55,243 - INFO - Processing file: 1037.mid
# 2024-09-18 00:55:56,769 - INFO - Finished processing file: 1032.mid
# 2024-09-18 00:55:57,149 - INFO - Processing file: 1038.mid
# 2024-09-18 00:55:57,150 - INFO - Processed 39 files
# 2024-09-18 00:55:57,152 - INFO - Processed 40 files
# 2024-09-18 00:56:06,074 - INFO - Finished processing file: 1035.mid
# 2024-09-18 00:56:06,307 - INFO - Processing file: 1039.mid
# 2024-09-18 00:56:07,504 - INFO - Finished processing file: 1034.mid
# 2024-09-18 00:56:07,741 - INFO - Processing file: 104.mid
# 2024-09-18 00:56:07,741 - INFO - Processed 41 files
# 2024-09-18 00:56:07,743 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:56:07,744 - INFO - Processed 42 files
# 2024-09-18 00:56:10,049 - INFO - Finished processing file: 1037.mid
# 2024-09-18 00:56:10,285 - INFO - Processing file: 1040.mid
# 2024-09-18 00:56:11,559 - INFO - Finished processing file: 1038.mid
# 2024-09-18 00:56:11,840 - INFO - Processing file: 1041.mid
# 2024-09-18 00:56:19,278 - INFO - Finished processing file: 1036.mid
# 2024-09-18 00:56:19,634 - INFO - Processing file: 1042.mid
# 2024-09-18 00:56:19,635 - INFO - Processed 43 files
# 2024-09-18 00:56:19,637 - INFO - Processed 44 files
# 2024-09-18 00:56:19,639 - INFO - Processed 45 files
# 2024-09-18 00:56:22,041 - INFO - Finished processing file: 104.mid
# 2024-09-18 00:56:22,259 - INFO - Processing file: 1043.mid
# 2024-09-18 00:56:27,976 - INFO - Finished processing file: 1041.mid
# 2024-09-18 00:56:28,179 - INFO - Processing file: 1044.mid
# 2024-09-18 00:56:29,450 - INFO - Finished processing file: 1040.mid
# 2024-09-18 00:56:29,640 - INFO - Processing file: 1045.mid
# 2024-09-18 00:56:30,065 - INFO - Finished processing file: 1039.mid
# 2024-09-18 00:56:30,326 - INFO - Processing file: 1046.mid
# 2024-09-18 00:56:30,326 - INFO - Processed 46 files
# 2024-09-18 00:56:30,330 - INFO - Processed 47 files
# 2024-09-18 00:56:30,331 - INFO - Processed 48 files
# 2024-09-18 00:56:30,337 - INFO - Processed 49 files
# 2024-09-18 00:56:33,796 - INFO - Finished processing file: 1042.mid
# 2024-09-18 00:56:34,100 - INFO - Processing file: 1047.mid
# 2024-09-18 00:56:34,101 - INFO - Processed 50 files
# 2024-09-18 00:56:41,482 - INFO - Finished processing file: 1044.mid
# 2024-09-18 00:56:41,728 - INFO - Processing file: 1048.mid
# 2024-09-18 00:56:44,189 - INFO - Finished processing file: 1043.mid
# 2024-09-18 00:56:44,526 - INFO - Processing file: 1049.mid
# 2024-09-18 00:56:44,526 - INFO - Processed 51 files
# 2024-09-18 00:56:44,529 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:56:44,531 - INFO - Processed 52 files
# 2024-09-18 00:56:45,910 - INFO - Finished processing file: 1045.mid
# 2024-09-18 00:56:46,123 - INFO - Processing file: 105.mid
# 2024-09-18 00:56:46,124 - INFO - Processed 53 files
# 2024-09-18 00:56:52,717 - INFO - Finished processing file: 1047.mid
# 2024-09-18 00:56:53,041 - INFO - Processing file: 1050.mid
# 2024-09-18 00:56:54,902 - INFO - Finished processing file: 1046.mid
# 2024-09-18 00:56:55,142 - INFO - Processing file: 1051.mid
# 2024-09-18 00:56:55,142 - INFO - Processed 54 files
# 2024-09-18 00:56:55,145 - INFO - Processed 55 files
# 2024-09-18 00:56:55,792 - INFO - Finished processing file: 1048.mid
# 2024-09-18 00:56:56,052 - INFO - Processing file: 1052.mid
# 2024-09-18 00:56:56,053 - INFO - Processed 56 files
# 2024-09-18 00:56:59,298 - INFO - Finished processing file: 1049.mid
# 2024-09-18 00:56:59,549 - INFO - Processing file: 1053.mid
# 2024-09-18 00:56:59,549 - INFO - Processed 57 files
# 2024-09-18 00:57:07,522 - INFO - Finished processing file: 105.mid
# 2024-09-18 00:57:07,749 - INFO - Processing file: 1054.mid
# 2024-09-18 00:57:07,749 - INFO - Processed 58 files
# 2024-09-18 00:57:09,308 - INFO - Finished processing file: 1052.mid
# 2024-09-18 00:57:09,630 - INFO - Processing file: 1055.mid
# 2024-09-18 00:57:10,057 - INFO - Finished processing file: 1051.mid
# 2024-09-18 00:57:10,284 - INFO - Processing file: 1056.mid
# 2024-09-18 00:57:13,038 - INFO - Finished processing file: 1050.mid
# 2024-09-18 00:57:13,310 - INFO - Processing file: 1057.mid
# 2024-09-18 00:57:13,310 - INFO - Processed 59 files
# 2024-09-18 00:57:13,313 - INFO - Processed 60 files
# 2024-09-18 00:57:13,314 - INFO - Processed 61 files
# 2024-09-18 00:57:13,315 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:57:17,904 - INFO - Finished processing file: 1053.mid
# 2024-09-18 00:57:18,136 - INFO - Processing file: 1058.mid
# 2024-09-18 00:57:18,136 - INFO - Processed 62 files
# 2024-09-18 00:57:24,753 - INFO - Finished processing file: 1055.mid
# 2024-09-18 00:57:24,959 - INFO - Processing file: 1059.mid
# 2024-09-18 00:57:25,748 - INFO - Finished processing file: 1056.mid
# 2024-09-18 00:57:26,074 - INFO - Processing file: 106.mid
# 2024-09-18 00:57:28,713 - INFO - Finished processing file: 1057.mid
# 2024-09-18 00:57:28,747 - INFO - Finished processing file: 1054.mid
# 2024-09-18 00:57:29,277 - INFO - Processing file: 1060.mid
# 2024-09-18 00:57:29,291 - INFO - Processing file: 1061.mid
# 2024-09-18 00:57:29,292 - INFO - Processed 63 files
# 2024-09-18 00:57:29,294 - INFO - Processed 64 files
# 2024-09-18 00:57:29,296 - INFO - Processed 65 files
# 2024-09-18 00:57:29,300 - INFO - Processed 66 files
# 2024-09-18 00:57:31,570 - INFO - Finished processing file: 1058.mid
# 2024-09-18 00:57:31,794 - INFO - Processing file: 1062.mid
# 2024-09-18 00:57:31,794 - INFO - Processed 67 files
# 2024-09-18 00:57:40,182 - INFO - Finished processing file: 1060.mid
# 2024-09-18 00:57:40,383 - INFO - Processing file: 1063.mid
# 2024-09-18 00:57:40,619 - INFO - Finished processing file: 1059.mid
# 2024-09-18 00:57:40,952 - INFO - Processing file: 1064.mid
# 2024-09-18 00:57:40,952 - INFO - Processed 68 files
# 2024-09-18 00:57:46,199 - INFO - Finished processing file: 1061.mid
# 2024-09-18 00:57:46,415 - INFO - Processing file: 1065.mid
# 2024-09-18 00:57:46,647 - INFO - Finished processing file: 1062.mid
# 2024-09-18 00:57:46,872 - INFO - Processing file: 1066.mid
# 2024-09-18 00:57:52,236 - INFO - Finished processing file: 106.mid
# 2024-09-18 00:57:52,416 - INFO - Processing file: 1067.mid
# 2024-09-18 00:57:52,417 - INFO - Processed 69 files
# 2024-09-18 00:57:52,419 - INFO - Processed 70 files
# 2024-09-18 00:57:52,420 - INFO - Processed 71 files
# 2024-09-18 00:57:52,421 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:57:52,431 - INFO - Processed 72 files
# 2024-09-18 00:57:54,054 - INFO - Finished processing file: 1064.mid
# 2024-09-18 00:57:54,311 - INFO - Processing file: 1068.mid
# 2024-09-18 00:57:57,683 - INFO - Finished processing file: 1063.mid
# 2024-09-18 00:57:58,062 - INFO - Processing file: 1069.mid
# 2024-09-18 00:57:58,063 - INFO - Processed 73 files
# 2024-09-18 00:57:58,065 - INFO - Processed 74 files
# 2024-09-18 00:58:01,595 - INFO - Finished processing file: 1066.mid
# 2024-09-18 00:58:01,813 - INFO - Processing file: 107.mid
# 2024-09-18 00:58:04,995 - INFO - Finished processing file: 1065.mid
# 2024-09-18 00:58:05,305 - INFO - Processing file: 1070.mid
# 2024-09-18 00:58:05,306 - INFO - Processed 75 files
# 2024-09-18 00:58:05,311 - INFO - Processed 76 files
# 2024-09-18 00:58:10,893 - INFO - Finished processing file: 1067.mid
# 2024-09-18 00:58:11,142 - INFO - Processing file: 1071.mid
# 2024-09-18 00:58:11,143 - INFO - Processed 77 files
# 2024-09-18 00:58:16,802 - INFO - Finished processing file: 1068.mid
# 2024-09-18 00:58:17,013 - INFO - Processing file: 1072.mid
# 2024-09-18 00:58:17,014 - INFO - Processed 78 files
# 2024-09-18 00:58:18,396 - INFO - Finished processing file: 1069.mid
# 2024-09-18 00:58:18,731 - INFO - Processing file: 1073.mid
# 2024-09-18 00:58:18,731 - INFO - Processed 79 files
# 2024-09-18 00:58:21,271 - INFO - Finished processing file: 1070.mid
# 2024-09-18 00:58:21,524 - INFO - Processing file: 1074.mid
# 2024-09-18 00:58:22,659 - INFO - Finished processing file: 107.mid
# 2024-09-18 00:58:23,000 - INFO - Processing file: 1075.mid
# 2024-09-18 00:58:23,001 - INFO - Processed 80 files
# 2024-09-18 00:58:23,003 - INFO - Processed 81 files
# 2024-09-18 00:58:23,004 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:58:29,228 - INFO - Finished processing file: 1072.mid
# 2024-09-18 00:58:29,405 - INFO - Processing file: 1076.mid
# 2024-09-18 00:58:30,006 - INFO - Finished processing file: 1071.mid
# 2024-09-18 00:58:30,225 - INFO - Processing file: 1077.mid
# 2024-09-18 00:58:30,227 - INFO - Processed 82 files
# 2024-09-18 00:58:30,228 - INFO - Processed 83 files
# 2024-09-18 00:58:32,701 - INFO - Finished processing file: 1073.mid
# 2024-09-18 00:58:33,090 - INFO - Processing file: 1078.mid
# 2024-09-18 00:58:33,090 - INFO - Processed 84 files
# 2024-09-18 00:58:36,476 - INFO - Finished processing file: 1074.mid
# 2024-09-18 00:58:36,716 - INFO - Processing file: 1079.mid
# 2024-09-18 00:58:36,717 - INFO - Processed 85 files
# 2024-09-18 00:58:41,269 - INFO - Finished processing file: 1075.mid
# 2024-09-18 00:58:41,509 - INFO - Processing file: 108.mid
# 2024-09-18 00:58:41,509 - INFO - Processed 86 files
# 2024-09-18 00:58:45,746 - INFO - Finished processing file: 1077.mid
# 2024-09-18 00:58:46,030 - INFO - Processing file: 1080.mid
# 2024-09-18 00:58:49,844 - INFO - Finished processing file: 1078.mid
# 2024-09-18 00:58:50,090 - INFO - Processing file: 1081.mid
# 2024-09-18 00:58:55,208 - INFO - Finished processing file: 1079.mid
# 2024-09-18 00:58:55,520 - INFO - Processing file: 1082.mid
# 2024-09-18 00:58:59,316 - INFO - Finished processing file: 1076.mid
# 2024-09-18 00:58:59,534 - INFO - Processing file: 1083.mid
# 2024-09-18 00:58:59,534 - INFO - Processed 87 files
# 2024-09-18 00:58:59,537 - INFO - Processed 88 files
# 2024-09-18 00:58:59,538 - INFO - Processed 89 files
# 2024-09-18 00:58:59,541 - INFO - Processed 90 files
# 2024-09-18 00:59:00,195 - INFO - Finished processing file: 108.mid
# 2024-09-18 00:59:00,528 - INFO - Processing file: 1084.mid
# 2024-09-18 00:59:00,528 - INFO - Processed 91 files
# 2024-09-18 00:59:00,530 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:59:02,136 - INFO - Finished processing file: 1081.mid
# 2024-09-18 00:59:02,402 - INFO - Processing file: 1085.mid
# 2024-09-18 00:59:02,901 - INFO - Finished processing file: 1080.mid
# 2024-09-18 00:59:03,127 - INFO - Processing file: 1086.mid
# 2024-09-18 00:59:03,129 - INFO - Processed 92 files
# 2024-09-18 00:59:03,131 - INFO - Processed 93 files
# 2024-09-18 00:59:11,821 - INFO - Finished processing file: 1082.mid
# 2024-09-18 00:59:12,029 - INFO - Processing file: 1087.mid
# 2024-09-18 00:59:12,030 - INFO - Processed 94 files
# 2024-09-18 00:59:12,279 - INFO - Finished processing file: 1083.mid
# 2024-09-18 00:59:12,509 - INFO - Processing file: 1088.mid
# 2024-09-18 00:59:12,510 - INFO - Processed 95 files
# 2024-09-18 00:59:17,217 - INFO - Finished processing file: 1085.mid
# 2024-09-18 00:59:18,658 - INFO - Finished processing file: 1084.mid
# 2024-09-18 00:59:18,858 - INFO - Processed 96 files
# 2024-09-18 00:59:18,860 - INFO - Processed 97 files
# 2024-09-18 00:59:25,430 - INFO - Finished processing file: 1087.mid
# 2024-09-18 00:59:26,346 - INFO - Finished processing file: 1086.mid
# 2024-09-18 00:59:26,562 - INFO - Processed 98 files
# 2024-09-18 00:59:26,564 - INFO - Processed 99 files
# 2024-09-18 00:59:27,421 - INFO - Finished processing file: 1088.mid
# 2024-09-18 00:59:27,693 - INFO - Processed 100 files
# 2024-09-18 00:59:27,694 - INFO -   Tonal stability: 0.00
# 2024-09-18 00:59:27,704 - INFO -   Rhythm consistency: 0.57
# 2024-09-18 00:59:27,705 - INFO -   Consonance ratio: 0.84
# 2024-09-18 00:59:27,705 - INFO -   Dissonance ratio: 0.16
# 2024-09-18 00:59:27,706 - INFO -   Melodic similarity: 0.09
# 2024-09-18 00:59:27,706 - INFO -   Tonal stability: 0.00
